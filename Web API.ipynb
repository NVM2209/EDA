# %% [markdown]
# # WEB API
# APPLICATION PROGRAMMING INTERFACE

# %%
import pandas as pd

ds=pd.read_csv("age_salary.csv")

ds
# Out:
#    index   Nation purchased_item   salary   age
# 0      0    India             No  66777.0  23.0
# 1      1   Russia            Yes  87878.0  24.0
# 2      2  Germany             No  34559.0   NaN
# 3      3    India            Yes  40000.0  26.0
# 4      4  Germany            Yes      NaN  21.0
# 5      5   Russia             No  45000.0   NaN
# 6      6  Germany            Yes  89993.0  62.0
# 7      7    India             No  55555.0  24.0
# 8      8   Russia            Yes      NaN  45.0
# 9      9  Germany            Yes  67222.0  53.0

# %%
df=pd.read_csv('concreate_data.csv')

df
# Out:
#       Cement  Blast  Fly Ash  Water  Superplasticizer      CA     FA  Age  \
# 0      540.0    0.0      0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0      0.0  162.0               2.5  1055.0  676.0   28
# 2      332.5  142.5      0.0  228.0               0.0   932.0  594.0  270
# 3      332.5  142.5      0.0  228.0               0.0   932.0  594.0  365
# 4      198.6  132.4      0.0  192.0               0.0   978.4  825.5  360
# ...      ...    ...      ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0     90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0    115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4    108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7      0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5     78.3  200.6               8.6   864.5  761.5   28
#
#         CMS
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05
# ...

# %%
dv=pd.read_csv('emp1.csv')

dv
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
dv=pd.read_csv('emp1.csv',index_col=['SNo'])    #making index column as serial no

dv
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
import numpy as np

dv=pd.read_csv('emp1.csv',dtype={'Salary':np.float64})

print(dv.dtypes)
# Out:
# SNo          int64
# Name        object
# Age        float64
# City        object
# Country     object
# Salary     float64
# dtype: object

# %% [markdown]
# object means that we do have string data /category data in name ,city and country

# %%
dv['Salary'].max()
# Out:
# 67666.0

# %%
dv['Salary'].min()
# Out:
# 3900.0

# %%
dv['Salary'].plot()
# Out:
# <AxesSubplot:>

# %%
#loading a dataframe inside the dataset


dv1=pd.DataFrame(data=dv)

dv1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
dv1.loc[:,'Salary']
# Out:
# 0     20000.0
# 1      3900.0
# 2      8000.0
# 3     66672.0
# 4         NaN
# 5     30007.0
# 6      8300.0
# 7     54666.0
# 8     67666.0
# 9      8888.0
# 10    66672.0
# 11    34344.0
# 12    30007.0
# 13     8300.0
# 14    54666.0
# 15    67666.0
# 16     8888.0
# 17        NaN
# 18    34432.0
# 19    34534.0
# 20    33451.0
# 21        NaN
# Name: Salary, dtype: float64

# %%
dv1.loc[:,'City']
# Out:
# 0       Toronto
# 1       Edmonto
# 2       Toronto
# 3      HongKong
# 4           NaN
# 5      HongKong
# 6       BayArea
# 7     Hyderabad
# 8       newyork
# 9       newyork
# 10     HongKong
# 11          NaN
# 12     HongKong
# 13          NaN
# 14    Hyderabad
# 15      newyork
# 16      newyork
# 17      Edmonto
# 18        Congo
# 19       Angola
# 20      Finland
# 21       London
# Name: City, dtype: object

# %%
dv1.iloc[:,2]
# Out:
# 0     28.0
# 1     31.0
# 2     34.0
# 3     26.0
# 4     30.0
# 5      NaN
# 6     43.0
# 7     38.0
# 8     50.0
# 9      NaN
# 10    26.0
# 11    30.0
# 12    22.0
# 13    43.0
# 14    38.0
# 15     NaN
# 16    27.0
# 17    31.0
# 18    34.0
# 19    32.0
# 20    26.0
# 21    27.0
# Name: Age, dtype: float64

# %%
dv1.iloc[:,3:5]
# Out:
#          City  Country
# 0     Toronto   Canada
# 1     Edmonto   Canada
# 2     Toronto   Canada
# 3    HongKong     Asia
# 4         NaN  America
# 5    HongKong     Asia
# 6     BayArea  America
# 7   Hyderabad     Asia
# 8     newyork  America
# 9     newyork  America
# 10   HongKong     Asia
# 11        NaN  America
# 12   HongKong     Asia
# 13        NaN  America
# 14  Hyderabad     Asia
# 15    newyork  America
# 16    newyork  America
# 17    Edmonto   Canada
# 18      Congo   Africa
# 19     Angola   Africa
# 20    Finland   Europe
# 21     London   Europe

# %%
dv1.iloc[15:20,3:5]
# Out:
#        City  Country
# 15  newyork  America
# 16  newyork  America
# 17  Edmonto   Canada
# 18    Congo   Africa
# 19   Angola   Africa

# %% [markdown]
# NEGATIVE INDEXING (iloc)

# %%
dv1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
dv1.iloc[:,-1]
# Out:
# 0     20000.0
# 1      3900.0
# 2      8000.0
# 3     66672.0
# 4         NaN
# 5     30007.0
# 6      8300.0
# 7     54666.0
# 8     67666.0
# 9      8888.0
# 10    66672.0
# 11    34344.0
# 12    30007.0
# 13     8300.0
# 14    54666.0
# 15    67666.0
# 16     8888.0
# 17        NaN
# 18    34432.0
# 19    34534.0
# 20    33451.0
# 21        NaN
# Name: Salary, dtype: float64

# %%
dv1.iloc[1:4,-3]
# Out:
# 1     Edmonto
# 2     Toronto
# 3    HongKong
# Name: City, dtype: object

# %%
dv1.iloc[1:2,-2]
# Out:
# 1    Canada
# Name: Country, dtype: object

# %%
dv1.iloc[:,-3:-1]
# Out:
#          City  Country
# 0     Toronto   Canada
# 1     Edmonto   Canada
# 2     Toronto   Canada
# 3    HongKong     Asia
# 4         NaN  America
# 5    HongKong     Asia
# 6     BayArea  America
# 7   Hyderabad     Asia
# 8     newyork  America
# 9     newyork  America
# 10   HongKong     Asia
# 11        NaN  America
# 12   HongKong     Asia
# 13        NaN  America
# 14  Hyderabad     Asia
# 15    newyork  America
# 16    newyork  America
# 17    Edmonto   Canada
# 18      Congo   Africa
# 19     Angola   Africa
# 20    Finland   Europe
# 21     London   Europe

# %%
dv1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
#count operation gives you how amny row are present.Total number of count.

dv1.count()
# Out:
# SNo        22
# Name       22
# Age        19
# City       19
# Country    22
# Salary     19
# dtype: int64

# %%
dv1['Name'].count()
# Out:
# 22

# %%
dv1['Name'].unique()    #unique names which is appearing in 2-3 times
# Out:
# array(['Tom', 'Lee', 'Dave', 'Anik', 'kamal', 'Geet', 'Steven', 'Ram',
#        'hari', 'yami', 'Andrew', 'soham', 'Grig', 'Kiara'], dtype=object)

# %%
dv1['Name'].nunique()   # nunique will giev you total /sum of unique value in counts.
# Out:
# 14

# %%
dv1.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        3
# City       3
# Country    0
# Salary     3
# dtype: int64

# %%
dv1['Country'].unique()
# Out:
# array(['Canada', 'Asia', 'America', 'Africa', 'Europe'], dtype=object)

# %%
dv1["Country"].nunique()
# Out:
# 5

# %%
#describe function - will show the description of particular column


print(dv1['Name'].describe())
# Out:
# count      22
# unique     14
# top       Lee
# freq        2
# Name: Name, dtype: object

# %%
dv1.describe()   # here it will take ponly numerical data column
# Out:
#              SNo        Age        Salary
# count  22.000000  19.000000     19.000000
# mean   12.090909  32.421053  33739.947368
# std     6.927578   7.174924  23151.188084
# min     1.000000  22.000000   3900.000000
# 25%     6.250000  27.000000   8888.000000
# 50%    12.500000  31.000000  33451.000000
# 75%    17.750000  36.000000  54666.000000
# max    23.000000  50.000000  67666.000000

# %%
dv1.describe(include='all')    # here it will give you details of number ,string,float columns
# Out:
#               SNo Name        Age      City  Country        Salary
# count   22.000000   22  19.000000        19       22     19.000000
# unique        NaN   14        NaN        10        5           NaN
# top           NaN  Lee        NaN  HongKong  America           NaN
# freq          NaN    2        NaN         4        8           NaN
# mean    12.090909  NaN  32.421053       NaN      NaN  33739.947368
# std      6.927578  NaN   7.174924       NaN      NaN  23151.188084
# min      1.000000  NaN  22.000000       NaN      NaN   3900.000000
# 25%      6.250000  NaN  27.000000       NaN      NaN   8888.000000
# 50%     12.500000  NaN  31.000000       NaN      NaN  33451.000000
# 75%     17.750000  NaN  36.000000       NaN      NaN  54666.000000
# max     23.000000  NaN  50.000000       NaN      NaN  67666.000000

# %% [markdown]
# DROPING ROWS AND COLUMNS IN PANDAS

# %% [markdown]
# If there is certain missing data( df.isnull().sum()) so we can drop those data using drop method .

# %%
dv1.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        3
# City       3
# Country    0
# Salary     3
# dtype: int64

# %%
dx=dv1.dropna(axis=0)   # means drop any null data. axis=0 means rows ,axis=1 means columns.inoriginal dataframes there is no changes (dv1)only in dx

# %%
dx
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
dx.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        0
# City       0
# Country    0
# Salary     0
# dtype: int64

# %%
dv1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %% [markdown]
# #we can retain the changes into the original one.Nan data using inplace=True  stored permanently in original dataframe .which is by default false.

# %%
dv1.dropna(axis=0,inplace=True) # so here changes are made in original dataframe as well

# %%
dv1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
dv1.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        0
# City       0
# Country    0
# Salary     0
# dtype: int64

# %%
dv1.drop('Name',axis=1,inplace=True) # if we want to drop a column use axis=1

# %%
dv1
# Out:
#     SNo   Age       City  Country   Salary
# 0     1  28.0    Toronto   Canada  20000.0
# 1     2  31.0    Edmonto   Canada   3900.0
# 2     3  34.0    Toronto   Canada   8000.0
# 3     4  26.0   HongKong     Asia  66672.0
# 6     7  43.0    BayArea  America   8300.0
# 7     8  38.0  Hyderabad     Asia  54666.0
# 8     9  50.0    newyork  America  67666.0
# 10   12  26.0   HongKong     Asia  66672.0
# 12   14  22.0   HongKong     Asia  30007.0
# 14   16  38.0  Hyderabad     Asia  54666.0
# 16   18  27.0    newyork  America   8888.0
# 18   20  34.0      Congo   Africa  34432.0
# 19   21  32.0     Angola   Africa  34534.0
# 20   22  26.0    Finland   Europe  33451.0

# %%
dv1.drop('SNo',axis=1,inplace=True)

# %%
dv1
# Out:
#      Age       City  Country   Salary
# 0   28.0    Toronto   Canada  20000.0
# 1   31.0    Edmonto   Canada   3900.0
# 2   34.0    Toronto   Canada   8000.0
# 3   26.0   HongKong     Asia  66672.0
# 6   43.0    BayArea  America   8300.0
# 7   38.0  Hyderabad     Asia  54666.0
# 8   50.0    newyork  America  67666.0
# 10  26.0   HongKong     Asia  66672.0
# 12  22.0   HongKong     Asia  30007.0
# 14  38.0  Hyderabad     Asia  54666.0
# 16  27.0    newyork  America   8888.0
# 18  34.0      Congo   Africa  34432.0
# 19  32.0     Angola   Africa  34534.0
# 20  26.0    Finland   Europe  33451.0

# %%
dv1.drop(0,axis=0,inplace=True) # to remove/drop any row use axis=0

# %%
dv1
# Out:
#      Age       City  Country   Salary
# 1   31.0    Edmonto   Canada   3900.0
# 2   34.0    Toronto   Canada   8000.0
# 3   26.0   HongKong     Asia  66672.0
# 6   43.0    BayArea  America   8300.0
# 7   38.0  Hyderabad     Asia  54666.0
# 8   50.0    newyork  America  67666.0
# 10  26.0   HongKong     Asia  66672.0
# 12  22.0   HongKong     Asia  30007.0
# 14  38.0  Hyderabad     Asia  54666.0
# 16  27.0    newyork  America   8888.0
# 18  34.0      Congo   Africa  34432.0
# 19  32.0     Angola   Africa  34534.0
# 20  26.0    Finland   Europe  33451.0

# %%
dv1.drop(['City','Country'],axis=1,inplace=True)
dv1
# Out:
#      Age   Salary
# 1   31.0   3900.0
# 2   34.0   8000.0
# 3   26.0  66672.0
# 6   43.0   8300.0
# 7   38.0  54666.0
# 8   50.0  67666.0
# 10  26.0  66672.0
# 12  22.0  30007.0
# 14  38.0  54666.0
# 16  27.0   8888.0
# 18  34.0  34432.0
# 19  32.0  34534.0
# 20  26.0  33451.0

# %%
dv1.drop([1,2,3],axis=0,inplace=True)
dv1
# Out:
#      Age   Salary
# 6   43.0   8300.0
# 7   38.0  54666.0
# 8   50.0  67666.0
# 10  26.0  66672.0
# 12  22.0  30007.0
# 14  38.0  54666.0
# 16  27.0   8888.0
# 18  34.0  34432.0
# 19  32.0  34534.0
# 20  26.0  33451.0

# %% [markdown]
# # Data munging

# %% [markdown]
# Data munging means converting the data into different format.like .csv file into .html file

# %%
import pandas as pd

con=pd.read_csv('emp1.csv',index_col=0)

con
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
con.to_html('emp1test.html')

# %% [markdown]
# # PANDAS DATE TIME FUNCTION

# %%
import pandas as pd

d=pd.read_csv('hrdata.csv')
d
# Out:
#          Employee  hiredate  salary  sick day
# 0  Graham Chapman  02/11/21   50000        10
# 1     John Cleese  01/10/21   65000         8
# 2        Eric Bay  03/11/21   70000         9
# 3           Ron K  01/11/21   75000         5
# 4    Terry Gillam  08/11/21   80000         8

# %%
d=pd.to_datetime({'year':[2022],'month':[11],'day':[15]})  # we can provide any date using to_datetime format
d
# Out:
# 0   2022-11-15
# dtype: datetime64[ns]

# %%
#inside pandas to_datetime functions are present

ds['hiredate']=pd.to_datetime(ds['hiredate'])
ds
# Out:
#          Employee   hiredate  salary  sick day  Day  month  year
# 0  Graham Chapman 2021-02-11   50000        10   11      2  2021
# 1     John Cleese 2021-01-10   65000         8   10      1  2021
# 2        Eric Bay 2021-03-11   70000         9   11      3  2021
# 3           Ron K 2021-01-11   75000         5   11      1  2021
# 4    Terry Gillam 2021-08-11   80000         8   11      8  2021

# %% [markdown]
# DATE RANGE FUNCTION

# %% [markdown]
# date range  function inside this we can provide 2 parameters start date and end date
#
# pd.daterange(start date,end date,freq='D')
#
# #date format---> mm/dd/yy

# %%
daterange=pd.date_range(start='09/09/22',end='09/20/22',freq='D')

daterange
# Out:
# DatetimeIndex(['2022-09-09', '2022-09-10', '2022-09-11', '2022-09-12',
#                '2022-09-13', '2022-09-14', '2022-09-15', '2022-09-16',
#                '2022-09-17', '2022-09-18', '2022-09-19', '2022-09-20'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# freq=d will show various days coming inbetween start date and end date

# %%
daterange=pd.date_range(start='1/1/20',end='5/1/20',freq='M')
daterange
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30'], dtype='datetime64[ns]', freq='M')

# %%
#inside pandas functionality we have to write import datetime.

import pandas as pd

import datetime

dt=datetime.datetime.now()
print(dt)
# Out:
# 2022-11-15 17:15:37.304797

# %%
#Timedelta---> represent a duration,the difference between 2 dates or times. time delta will give date after 10 days

print(dt+pd.to_timedelta(10,unit='D'))
# Out:
# 2022-11-25 17:15:37.304797

# %%
print(dt+pd.to_timedelta(15,unit='D'))
# Out:
# 2022-11-30 17:15:37.304797

# %% [markdown]
# # PANDA'S SQL

# %% [markdown]
# We an select particular rows /columns in pandas also using panda's sql

# %%
import pandas as pd

df=pd.read_csv('emp1.csv')

print(df)
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1=pd.DataFrame(data=df,columns=['Name'])
df1
# Out:
#       Name
# 0      Tom
# 1      Lee
# 2     Dave
# 3     Anik
# 4    kamal
# 5     Geet
# 6   Steven
# 7      Ram
# 8     hari
# 9     yami
# 10    Anik
# 11   kamal
# 12    Geet
# 13  Steven
# 14     Ram
# 15    hari
# 16    yami
# 17     Lee
# 18  Andrew
# 19   soham
# 20    Grig
# 21   Kiara

# %%
# same statemnet can be written in MYSQL database by select name from table(here its dataframe)

# %%
df1=pd.DataFrame(data=df,columns=['Name','Age'])
df1
# Out:
#       Name   Age
# 0      Tom  28.0
# 1      Lee  31.0
# 2     Dave  34.0
# 3     Anik  26.0
# 4    kamal  30.0
# 5     Geet   NaN
# 6   Steven  43.0
# 7      Ram  38.0
# 8     hari  50.0
# 9     yami   NaN
# 10    Anik  26.0
# 11   kamal  30.0
# 12    Geet  22.0
# 13  Steven  43.0
# 14     Ram  38.0
# 15    hari   NaN
# 16    yami  27.0
# 17     Lee  31.0
# 18  Andrew  34.0
# 19   soham  32.0
# 20    Grig  26.0
# 21   Kiara  27.0

# %%
# TO SEE TOP FIVE ROWS /CLOUMNS

df[["Name","Age","Salary"]].head(5)
# Out:
#     Name   Age   Salary
# 0    Tom  28.0  20000.0
# 1    Lee  31.0   3900.0
# 2   Dave  34.0   8000.0
# 3   Anik  26.0  66672.0
# 4  kamal  30.0      NaN

# %%
# to see bottom 5 rows/columns


df[["Name","Age","Salary"]].tail(5)
# Out:
#       Name   Age   Salary
# 17     Lee  31.0      NaN
# 18  Andrew  34.0  34432.0
# 19   soham  32.0  34534.0
# 20    Grig  26.0  33451.0
# 21   Kiara  27.0      NaN

# %%
# to select a particular row with same name :-

df[df["Name"]=="Grig"]
# Out:
#     SNo  Name   Age     City Country   Salary
# 20   22  Grig  26.0  Finland  Europe  33451.0

# %%
#select * from df where "name"== grig AND salary>30000

#AND Operatoe will give data only if both conditions is TRUE.

df[(df['Name']=='Grig')&(df['Salary']>30000)]
# Out:
#     SNo  Name   Age     City Country   Salary
# 20   22  Grig  26.0  Finland  Europe  33451.0

# %%
#OR Operator will work if any one is true ,you will receive an answer.

df[(df['Name']=='Grig')|(df['Salary']>[65000])]

# %%
#select * from df where columns is null(Nan)

df[df["Salary"].isna()]    # slaary is missing i.e Nan
# Out:
#     SNo   Name   Age     City  Country  Salary
# 4     5  kamal  30.0      NaN  America     NaN
# 17   19    Lee  31.0  Edmonto   Canada     NaN
# 21   23  Kiara  27.0   London   Europe     NaN

# %%
df[df["Salary"].notna()]
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
# to drop all null values

df1=df.dropna()
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
df1=df.dropna(axis=0)
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
df.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        0
# City       0
# Country    0
# Salary     0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        0
# City       0
# Country    0
# Salary     0
# dtype: int64

# %% [markdown]
# # JOINS IN PANDAS

# %%
SQL JOINS- joins can be performed with concat,merge and join operations in pandas.

# %%
#1. Create a first dataframe


import pandas as pd

raw_data={'subject_id':['1','2','3','4','5'],'First_name':['Alex','Ancy','Anna','Amy','Alice'],'Last_name':['Anderson','Bay','Stone','Amon','paul']}

df_a=pd.DataFrame(raw_data,columns=['subject_id','First_name','Last_name'])
df_a
# Out:
#   subject_id First_name Last_name
# 0          1       Alex  Anderson
# 1          2       Ancy       Bay
# 2          3       Anna     Stone
# 3          4        Amy      Amon
# 4          5      Alice      paul

# %%
#create a second dataframe

raw_data={'subject_id':['4','5','6','7','8'],'First_name':['Billy','Boney','Bran','Batisan','Bruce'],'Last_name':['Ander','Bil','Silver','Amonly','Black']}

df_b=pd.DataFrame(raw_data,columns=['subject_id','First_name','Last_name'])
df_b
# Out:
#   subject_id First_name Last_name
# 0          4      Billy     Ander
# 1          5      Boney       Bil
# 2          6       Bran    Silver
# 3          7    Batisan    Amonly
# 4          8      Bruce     Black

# %%
#Union all operator

#concatenation basically glues all the df together

df_new=pd.concat([df_a,df_b],axis=0,ignore_index=True)

df_new
# Out:
#   subject_id First_name Last_name
# 0          1       Alex  Anderson
# 1          2       Ancy       Bay
# 2          3       Anna     Stone
# 3          4        Amy      Amon
# 4          5      Alice      paul
# 5          4      Billy     Ander
# 6          5      Boney       Bil
# 7          6       Bran    Silver
# 8          7    Batisan    Amonly
# 9          8      Bruce     Black

# %%
#create a third dataframe

raw_data={'subject_id':['1','2','3','4','5','6','7','8'],'Test_id':[21,34,56,78,90,21,45,67]}
df_n=pd.DataFrame(raw_data,columns=['subject_id','Test_id'])
df_n
# Out:
#   subject_id  Test_id
# 0          1       21
# 1          2       34
# 2          3       56
# 3          4       78
# 4          5       90
# 5          6       21
# 6          7       45
# 7          8       67

# %%
#merger operation is used if any one column is common in df and concat operation is used when all are same in columns .




pd.merge(df_new,df_n)
# Out:
#   subject_id First_name Last_name  Test_id
# 0          1       Alex  Anderson       21
# 1          2       Ancy       Bay       34
# 2          3       Anna     Stone       56
# 3          4        Amy      Amon       78
# 4          4      Billy     Ander       78
# 5          5      Alice      paul       90
# 6          5      Boney       Bil       90
# 7          6       Bran    Silver       21
# 8          7    Batisan    Amonly       45
# 9          8      Bruce     Black       67

# %%
#inner joins  ---> it produce only the set records that matches in both tables.(intersection data)

pd.merge(df_a,df_b,on='subject_id',how='inner')
# Out:
#   subject_id First_name_x Last_name_x First_name_y Last_name_y
# 0          4          Amy        Amon        Billy       Ander
# 1          5        Alice        paul        Boney         Bil

# %%
# outer joins---> show all data

pd.merge(df_a,df_b,on='subject_id',how='outer')
# Out:
#   subject_id First_name_x Last_name_x First_name_y Last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2         Ancy         Bay          NaN         NaN
# 2          3         Anna       Stone          NaN         NaN
# 3          4          Amy        Amon        Billy       Ander
# 4          5        Alice        paul        Boney         Bil
# 5          6          NaN         NaN         Bran      Silver
# 6          7          NaN         NaN      Batisan      Amonly
# 7          8          NaN         NaN        Bruce       Black
